# %%
import pandas as pd

popu = pd.read_csv(r'C:\Users\Lee\Desktop\Project\천안시 시각화\천안시_DataDir\천안시_유동인구데이터.CSV')
popu
# print(popu['ADNG_NM'].value_counts())
popu[popu['ADNG_NM']=='성환읍']
# Out:
#                                   ﻿"INDEX_KEY"  CRTR_YMD  CRTR_WEEK DWK_NM  \
# 9997      LI122100010085LI12210001008516969998  20201201         49      화
# 9998      LI122100010085LI12210001008516969999  20201201         49      화
# 9999     LI122100010085LI122100010085169610000  20201201         49      화
# 10000    LI122100010085LI122100010085169610001  20201201         49      화
# 10001    LI122100010085LI122100010085169610002  20201201         49      화
# ...                                        ...       ...        ...    ...
# 612983  LI122100010085LI1221000100851696612984  20201231         53      목
# 612984  LI122100010085LI1221000100851696612985  20201231         53      목
# 612985  LI122100010085LI1221000100851696612986  20201231         53      목
# 612986  LI122100010085LI1221000100851696612987  20201231         53      목
# 612987  LI122100010085LI1221000100851696612988  20201231         53      목
#
# ...
