# %%
import pandas as pd
import requests
import json

# %%
import pandas as pd
# c = pd.read_pickle(r'C:\Users\Lee\Desktop\천안시_DataDir\회사데이터\제조업체데이터byAPI.pickle')
# c
cp = pd.read_csv(r'C:\Users\Lee\Desktop\천안시_DataDir\회사데이터\산업단지데이터.csv',encoding='cp949')
cp.rename(columns={'공장대표주소(도로명)':'주소'},inplace=True)
cp.head()
# Out:
#             단지명         회사명                                            주소  \
# 0  천안산업기술일반산업단지     주식회사 두코     충청남도 천안시 서북구 직산읍 직산로 136, 생산관 2105호 (직산읍)
# 1    천안마정일반산업단지  (주)케이와이컴퍼니                    충청남도 천안시 서북구 직산읍 금곡로 52-20
# 2  천안산업기술일반산업단지    주식회사 바이콘           충청남도 천안시 서북구 직산읍 직산로 136, 생산관 2305호
# 3  천안산업기술일반산업단지     (주)인피닉스    충청남도 천안시 서북구 직산읍 직산로 136, 충남테크노파크 영상관 506호
# 4  천안산업기술일반산업단지    (주)에스피에스  충청남도 천안시 서북구 직산읍 직산로 136, 3102호(충남테크노파크 생산관)
#
#             전화번호   데이터 기준 일자
# 0      1644-3880  2022-06-23
# 1      1599-3176  2022-06-23
# 2      1566-7185  2022-06-23
# 3      1688-0201  2022-06-23
# 4  070-8871-5835  2022-06-23

# %%
searching =  '충청남도 천안시 서북구, 충남테크노파크 벤처관 1307호 (직산읍)'
url = 'https://dapi.kakao.com/v2/local/search/address.json?query={}'.format(searching)


headers = {'Authorization': 'KakaoAK {}'.format('1d49e941371e685a965fba06520cda68') }
data = requests.post(url,headers=headers)
result = json.loads(data.text)
result
# documents = result['documents']
# documents[0]
# print(documents)
# for data in documents:
#   print(data['address'])  
  # 127.0003429871931 ,37.57113559406886
# Out:
# {'documents': [],
#  'meta': {'is_end': True, 'pageable_count': 0, 'total_count': 0}}

# %%
from tqdm import tqdm
import pandas as pd
import requests
import json

cnt=0

addressCopy = cp.copy()
headers = {'Authorization': 'KakaoAK {}'.format('1d49e941371e685a965fba06520cda68') }
addressCopy['byAPI'] =None
for idx in tqdm(range(len(addressCopy))):
  try:

    address = addressCopy.at[idx,'주소']

    searching = address
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query={}'.format(searching)
    # headers = {'Authorization': 'KakaoAK {}'.format('c454c0e64688ce2bde2dfff9cceced87') }
    data = requests.post(url,headers=headers)
    result = json.loads(data.text)
    documents = result['documents']
    

    addressCopy.at[idx,'byAPI'] = documents[0]
  except:
    cnt+=1
    if cnt%50==0:
      print('쿼리값을 못찾는중:',cnt) 

    pass
# Out:
#   0%|          | 0/969 [00:00<?, ?it/s]
#  54%|█████▍    | 527/969 [00:28<00:22, 19.86it/s]
# 쿼리값을 못찾는중: 50
# 100%|██████████| 969/969 [00:51<00:00, 18.67it/s]

# %%
addressCopy[addressCopy['byAPI'].isna()]
# Out:
#               단지명          회사명  \
# 8    천안산업기술일반산업단지       (주)토비코
# 44   천안산업기술일반산업단지        나비스퀘어
# 48     천안풍세일반산업단지  일광금속 유한책임회사
# 59     천안풍세일반산업단지        (주)엔켐
# 66       천안백석농공단지     (주)셀아이콘랩
# ..            ...          ...
# 843     천안외국인투자지역   하나머티리얼즈(주)
# 846  천안산업기술일반산업단지       실버텍(주)
# 847  천안산업기술일반산업단지     (주)에이치앤비
# 862  천안산업기술일반산업단지    주식회사 케이티엘
# 883    천안풍세일반산업단지       (주)삼양사
#
#                                                     주소           전화번호  \
# 8       충청남도 천안시서북구 직산읍 삼은리 43-5번지 충남테크노파크 번영관 4101~4호  070-8610-0396
# 44               충청남도 천안시 서북구, 충남테크노파크 벤처관 1307호 (직산읍)  070-4045-7330
# 48                    충청남도 천안시 동남구 풍세면 보성리 799번지 외 1필지   055-744-2155
# 59                    충청남도 천안시 동남구 풍세면 용정리 984번지 외 1필지   043-653-0910
# 66                        충청남도 천안시 서북구 백석공단1로 58 (백석동)   042-335-7942
# ..                                                 ...            ...
# 843  충청남도 천안시 서북구 3공단3로 42, (백석동 711-1, 711) (백석동) ...   041-410-1013
# 846       충청남도 천안시서북구 직산읍 삼은리 43-5번지 충남테크노파크 생산관 3312호  041-1644-7377
# 847      충청남도 천안시서북구 직산읍 삼은리 43-1 번지 충남테크노파크 번영관 2401호  041-1577-4580
# 862  충청남도 천안시 서북구 직산읍 직산로 136, 번영관 4201호, 4202호, 4203호   031-671-1811
# 883           충청남도 천안시 동남구 풍세면 보성리 0-0번지 풍세일반산업단지 Z4-1    02-740-7191
#
#       데이터 기준 일자 byAPI
# 8    2022-06-23  None
# 44   2022-06-23  None
# 48   2022-06-23  None
# 59   2022-06-23  None
# 66   2022-06-23  None
# ..          ...   ...
# 843  2022-06-23  None
# 846  2022-06-23  None
# 847  2022-06-23  None
# 862  2022-06-23  None
# 883  2022-06-23  None
#
# [80 rows x 6 columns]

# %%
addressCopy.to_pickle(r'C:\Users\Lee\Desktop\천안시_DataDir\회사데이터\산업단지byAPI_0815.pickle')

# %%
# addressCopy.to_pickle(r'C:\Users\Lee\Desktop\천안시_DataDir\회사데이터\제조업체데이터byAPI.pickle')

# %%
isna_df = addressCopy[addressCopy['byAPI'].isna()]
isna_df
# Out:
#                            회사  \
# 30                       수덕산업
# 43             (유)한국타코닉 제1공장
# 47                (주) 동양엘리베이터
# 48                (주) 동양엘리베이터
# 52                  (주) 우진하이텍
# ...                       ...
# 3183                 후드메이트(주)
# 3184  후지필름일렉트로닉머티리얼즈매뉴팩처링코리아㈜
# 3189                 희성폴리머(주)
# 3190                       희영
# 3191                   히트텍(주)
#
#                                                      주소 byAPI
# 30                       충청남도 천안시 서북구 성환읍 복모리 280 외 1필지  None
# 43           충청남도 천안시 서북구 3공단2로 12(백석동, (유)한국타코닉) 외 1필지  None
# 47                    충청남도 천안시 서북구 성환읍 신방로 142-15 외 2필지  None
# 48                    충청남도 천안시 서북구 성환읍 신방로 142-15 외 2필지  None
# 52                       충청남도 천안시 동남구 성남면 용원리 245 외 3필지  None
# ...                                                 ...   ...
# 3183          충청남도 천안시동남구 안서동 산 120-1번지 호서대 신기술창업센타 304  None
# 3184  충청남도 천안시 서북구 2공단3로 79, 업성동624-3외 1필지(차암동4-3) (...  None
# 3189             충청남도 천안시 서북구 성환읍 천안대로 2131 (성환읍) 외 1필지  None
# 3190  충청남도 천안시 서북구 직산읍 금곡로 141 ((주)그린테크산업) (총 3 필지) ...  None
# 3191                          충청남도 천안시서북구 직산읍 마정리 522번지  None
#
# [634 rows x 3 columns]

# %%
string = '충청남도 천안시 서북구 2공단3로 79, 업성동624-3외 1필지(차암동4-3)'
s_list= string.split(' ')
s_list
# Out:
# ['충청남도', '천안시', '서북구', '2공단3로', '79,', '업성동624-3외', '1필지(차암동4-3)']

# %%
isna_df['c'] =None
